# %%
# 查看当前挂载的数据集目录, 该目录下的变更重启环境后会自动还原
# View dataset directory. 
# This directory will be recovered automatically after resetting environment. 
# !ls /home/aistudio/data

# %%
# 查看工作区文件, 该目录下的变更将会持久保存. 请及时清理不必要的文件, 避免加载过慢.
# View personal work directory. 
# All changes under this directory will be kept even after reset. 
# Please clean unnecessary files in time to speed up environment loading. 
# !ls /home/aistudio/work

# %%
# 如果需要进行持久化安装, 需要使用持久化路径, 如下方代码示例:
# If a persistence installation is required, 
# you need to use the persistence path as the following: 
# !mkdir /home/aistudio/external-libraries
# !pip install beautifulsoup4 -t /home/aistudio/external-libraries

# %%
# 同时添加如下代码, 这样每次环境(kernel)启动的时候只要运行下方代码即可: 
# Also add the following code, 
# so that every time the environment (kernel) starts, 
# just run the following code: 
import sys 
sys.path.append('/home/aistudio/external-libraries')

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.

# %%
# !unzip ./data/data103285/train_images.zip
# Out:
# Archive:  ./data/data103285/train_images.zip
# replace train_images/9733.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# !unzip ./data/data103285/test_images.zip
# Out:
# Archive:  ./data/data103285/test_images.zip
#    creating: test_images/
#   inflating: test_images/9733.jpg
#   inflating: test_images/63.jpg
#   inflating: test_images/6400.jpg
#   inflating: test_images/823.jpg
#   inflating: test_images/4217.jpg
#   inflating: test_images/3578.jpg
#   inflating: test_images/2666.jpg
#   inflating: test_images/5109.jpg
#   inflating: test_images/2100.jpg
#   inflating: test_images/4571.jpg
#   inflating: test_images/7078.jpg
#   inflating: test_images/1409.jpg
#   inflating: test_images/9055.jpg
#   inflating: test_images/6366.jpg
#   inflating: test_images/189.jpg
#   inflating: test_images/9041.jpg
#   inflating: test_images/6372.jpg
#   inflating: test_images/2114.jpg
#   inflating: test_images/4565.jpg
#   inflating: test_images/4203.jpg
#   inflating: test_images/2672.jpg
#   inflating: test_images/9727.jpg
#   inflating: test_images/6414.jpg
#   inflating: test_images/77.jpg
#   inflating: test_images/8439.jpg
# ...

# %%
# !cp ./data/data103285/train_label.csv ./train_label.csv

# %%
# !git clone https://gitee.com/paddlepaddle/PaddleOCR.git -b release/2.4
# Out:
# 正克隆到 'PaddleOCR'...
# remote: Enumerating objects: 33994, done.
# remote: Counting objects: 100% (8373/8373), done.
# remote: Compressing objects: 100% (3273/3273), done.
# remote: Total 33994 (delta 5794), reused 7352 (delta 4997), pack-reused 25621
# 接收对象中: 100% (33994/33994), 282.19 MiB | 6.22 MiB/s, 完成.
# 处理 delta 中: 100% (23655/23655), 完成.
# 检查连接... 完成。

# %%
# 安装依赖的工具箱
# !pip install --upgrade -r ../PaddleOCR/requirements.txt
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 2.1 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 KB 3.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.5/603.5 KB 2.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 KB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 2.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 1.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 59.3 kB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# ...

# %%
# 安装识别模型
# !wget https://paddleocr.bj.bcebos.com/PP-OCRv2/chinese/ch_PP-OCRv2_rec_infer.tar
# Out:
# --2022-05-04 18:14:06--  https://paddleocr.bj.bcebos.com/PP-OCRv2/chinese/ch_PP-OCRv2_rec_infer.tar
# 正在解析主机 paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 182.61.200.229, 182.61.200.195, 2409:8c04:1001:1002:0:ff:b001:368a
# 正在连接 paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|182.61.200.229|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度： 8875520 (8.5M) [application/x-tar]
# 正在保存至: “ch_PP-OCRv2_rec_infer.tar”
#
# ch_PP-OCRv2_rec_inf 100%[===================>]   8.46M  5.37MB/s    in 1.6s
#
# 2022-05-04 18:14:08 (5.37 MB/s) - 已保存 “ch_PP-OCRv2_rec_infer.tar” [8875520/8875520])

# %%
# 模型解压
# !tar xf ch_PP-OCRv2_rec_infer.tar

# %%
# !pip install paddlepaddle==2.2.0
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.2/108.2 MB 14.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
# %cd PaddleOCR
# Out:
# /home/aistudio/PaddleOCR

# %%
# !pwd
# Out:
# /home/aistudio/PaddleOCR

# %%
# !ls
# Out:
# benchmark  __init__.py	 ppocr	       README.md	 test_tipc
# configs    LICENSE	 PPOCRLabel    requirements.txt  tools
# deploy	   MANIFEST.in	 ppstructure   setup.py		 train.sh
# doc	   paddleocr.py  README_ch.md  StyleText

# %%
# # 对单张图片进行识别
# !python ./tools/infer/predict_rec.py --image_dir="/home/aistudio/test_images/3578.jpg" --rec_model_dir="../ch_PP-OCRv2_rec_infer"
# Out:
# [2022/05/06 15:47:03] root INFO: Predicts of /home/aistudio/test_images/3578.jpg:('福', 0.82231873)

# %%
# 安装检测模型
# !wget https://paddleocr.bj.bcebos.com/PP-OCRv2/chinese/ch_PP-OCRv2_det_infer.tar
# Out:
# --2022-05-06 16:00:12--  https://paddleocr.bj.bcebos.com/PP-OCRv2/chinese/ch_PP-OCRv2_det_infer.tar
# 正在解析主机 paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 182.61.200.229, 182.61.200.195, 2409:8c04:1001:1002:0:ff:b001:368a
# 正在连接 paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|182.61.200.229|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度： 3190272 (3.0M) [application/x-tar]
# 正在保存至: “ch_PP-OCRv2_det_infer.tar”
#
# ch_PP-OCRv2_det_inf 100%[===================>]   3.04M  3.42MB/s    in 0.9s
#
# 2022-05-06 16:00:13 (3.42 MB/s) - 已保存 “ch_PP-OCRv2_det_infer.tar” [3190272/3190272])

# %%
# !tar xf ch_PP-OCRv2_det_infer.tar

# %%
# 对单张图片进行目标检测
# !python ./tools/infer/predict_det.py --image_dir="/home/aistudio/test_images/3578.jpg" --det_model_dir="./ch_PP-OCRv2_det_infer"
# Out:
# [2022/05/06 16:05:27] root INFO: 3578.jpg	[]
#
# [2022/05/06 16:05:27] root INFO: The predict time of /home/aistudio/test_images/3578.jpg: 2.804593324661255
# [2022/05/06 16:05:27] root INFO: The visualized image saved in ./inference_results/det_res_3578.jpg

# %%
from tools.infer import utility
parser = utility.init_args()
parser
# Out:
# ArgumentParser(prog='ipykernel_launcher.py', usage=None, description=None, formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)

# %%
args = parser.parse_args('')
args
# Out:
# Namespace(benchmark=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir=None, cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det_algorithm='DB', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir=None, det_pse_box_thresh=0.85, det_pse_box_type='box', det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_polygon=False, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, gpu_mem=500, image_dir=None, ir_optim=True, is_visualize=True, label_list=['0', '180'], max_batch_size
# ...

# %%
from tools.infer import predict_rec
import os
from tqdm import tqdm
import pandas as pd

path = '/home/aistudio/test_images'
result = pd.DataFrame(columns=['new_name', 'value'])
for filename in tqdm(os.listdir(path)):
    args.image_dir = '/home/aistudio/test_images/{}'.format(filename)
    args.rec_model_dir = '../ch_PP-OCRv2_rec_infer'
    valid_image_file_list, rec_res = predict_rec.predict_ryt(args)
    tmp = {}
    tmp['new_name'] = filename
    tmp['value'] = rec_res
    result = result.append(tmp, ignore_index=True)

result
# Out:
#   0%|          | 51/50001 [00:16<4:49:16,  2.88it/s]/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   2%|▏         | 1146/50001 [06:22<4:31:34,  3.00it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12825/1733840042.py in <module>
#       9     args.image_dir = '/home/aistudio/train_images/{}'.format(filename)
#      10     args.rec_model_dir = '../ch_PP-OCRv2_rec_infer'
# ---> 11     valid_image_file_list, rec_res = predict_rec.predict_ryt(args)
#      12     tmp = {}
#      13     tmp['new_name'] = filename
#
# ...

# %%
args.image_dir = '/home/aistudio/test_images'
args.rec_model_dir = '../ch_PP-OCRv2_rec_infer'
args.batch_num = 64
valid_image_file_list, rec_res = predict_rec.predict_ryt(args)
rec_res
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [('邦佳洗衣', 0.94482225),
#  ('不锈钢配件大全', 0.9985511),
#  ('诊疗科目：中医科', 0.95636714),
#  ('210', 0.9972846),
#  ('电线电缆等', 0.85407),
#  ('20', 0.9791717),
#  ('进口滤纸 专业制造', 0.89961624),
#  ('', nan),
#  ('Qiwow', 0.84283704),
#  ('美蝶蓬', 0.8769048),
#  ('福', 0.3959454),
#  ('秀星空间', 0.5429203),
#  ('水电 本工', 0.8520233),
#  ('中文城名：江城名吃客服电话：027-87875310', 0.92638457),
#  ('水管安装', 0.9918862),
#  ('广州市体育传统项目学校', 0.98838407),
#  ('信阳申通快递', 0.95063525),
#  ('10', 0.6035134),
#  ('施冲百货综合商店', 0.9190499),
#  ('闲人免进', 0.9012858),
#  ('微各种水箱，电气焊、打黄油', 0.76701003),
#  ('向里20米', 0.96445334),
#  ('文', 0.99371827),
# ...

# %%
len(rec_res)
# Out:
# 10000

# %%
result = pd.DataFrame(columns=['new_name', 'value'])
for image_file, rec in zip(valid_image_file_list, rec_res):
    image_file = image_file.replace('/home/aistudio/test_images', '')
    tmp = {}
    tmp['new_name'] = image_file
    tmp['value'] = rec[0]
    result = result.append(tmp, ignore_index=True)

result
# Out:
#        new_name     value
# 0        /0.jpg      邦佳洗衣
# 1        /1.jpg   不锈钢配件大全
# 2       /10.jpg  诊疗科目：中医科
# 3      /100.jpg       210
# 4     /1000.jpg     电线电缆等
# ...         ...       ...
# 9995  /9995.jpg         东
# 9996  /9996.jpg       279
# 9997  /9997.jpg    公牛装饰开关
# 9998  /9998.jpg        专国
# 9999  /9999.jpg       乐之家
#
# [10000 rows x 2 columns]

# %%
result.to_csv('./predict1-paddleOCR-aistudio.csv', index=False)
